# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
 One row represents one content page observed during a specific month.

Time Window:
March 2026

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
Goal:
Estimate a refresh priority score for pages that may benefit from content updates.
excluded:
Future performance metrics are excluded because they would not be available at the decision moment and could introduce data leakage.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
Observation:
Each row represents a single content page record. The page identifier appears once per row at the selected analysis grain.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
### Data Limits

* The dataset cannot prove why a page's performance changed; it only shows observed patterns.
* External factors such as Google updates, competitors, and seasonality are not captured.
* Some pages may have limited historical data.
* Window overlaps and missing observations can affect trend analysis.
* Findings should be interpreted as directional rather than causal.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [done ] Every section above is filled — markdown thinking AND the code that backs it
# - [done ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [done ] No client names, URLs, or private queries anywhere
# - [done ] My claims use careful words: observed, measured, directional, decision-support
# - [done ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
