# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
#classification
""" My Lane as an ML Task
I chose the Content Refresh lane.
The ML task is a scoring problem.
The goal is to assign a refresh priority score to each page so that content teams
 can focus on the pages most likely to benefit from updates."""

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
"""
The ideal target would be the future traffic improvement after a content update.
Since update outcomes are not available in the starter dataset,
I will use a proxy based on declining traffic indicators and engagement signals.
"""

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
 """
Success will be measured using Precision@50.
This metric evaluates whether the highest-priority pages identified by the
model are actually valuable candidates for content refresh.
"""

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# !git clone https://github.com/aliraza0321/flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 103 (delta 23), reused 78 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (103/103), 1.84 MiB | 12.98 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# %cd flyrank-ml-internship
# Out:
# /content/flyrank-ml-internship

# %%
import pandas as pd

df=pd.read_csv("./data/raw/content_refresh_anonymized.csv")
print(df.head())
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
#Refresh pages older than 365 days.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ confirm] Every section above is filled — markdown thinking AND the code that backs it
# - [ confirm] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [confirm ] No client names, URLs, or private queries anywhere
# - [confirm ] My claims use careful words: observed, measured, directional, decision-support
# - [confirm ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
